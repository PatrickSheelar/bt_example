# %%
from bt_example import backtest

# %%
backtest.run_backtest()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#                   spy        agg
# Date
# 2010-01-04  86.580757  69.574394
# 2010-01-05  86.809937  69.890854
# 2010-01-06  86.871071  69.850464
# 2010-01-07  87.237755  69.769676
# 2010-01-08  87.528069  69.810074
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.13it/s]
# Stat                 s1
# -------------------  ----------
# Start                2010-01-03
# End                  2024-09-17
# Risk-free rate       0.00%
#
# Total Return         223.51%
# Daily Sharpe         0.96
# Daily Sortino        1.48
# CAGR                 8.31%
# Max Drawdown         -19.87%
# Calmar Ratio         0.42
#
# MTD                  0.98%
# 3m                   4.43%
# 6m                   8.99%
# YTD                  12.21%
# 1Y                   19.40%
# 3Y (ann.)            4.38%
# ...
